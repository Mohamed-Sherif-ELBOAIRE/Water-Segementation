# %% [markdown]
#  ### Import Libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from sklearn.metrics import jaccard_score, precision_score, recall_score, f1_score
import tifffile as tiff
from PIL import Image

import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, UpSampling2D, SpatialDropout2D,concatenate, Activation, Conv2DTranspose, MaxPool2D, BatchNormalization, Dropout
from tensorflow.keras import Model, layers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.models import load_model
from keras import layers
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix



from tensorflow.keras.initializers import HeNormal
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Load and Explore Dataset

# %%
def load_images_and_labels(data_path):
    images_path = os.path.join(data_path, 'images')
    labels_path = os.path.join(data_path, 'labels')
    
    image_files = [f for f in os.listdir(images_path) if f.endswith('.tif')]
    label_files = [f for f in os.listdir(labels_path) if f.endswith('.png')]
    
    images = []
    labels = []
    
    for img_file, lbl_file in zip(image_files, label_files):
        
        img = tiff.imread(os.path.join(images_path, img_file))
        
        lbl = Image.open(os.path.join(labels_path, lbl_file))
        lbl = np.array(lbl).astype(np.float32)
        
        # lbl = np.where(lbl > 0.5, 1, 0).astype(np.float32)
        
        
        images.append(img)
        labels.append(lbl)
    
    return np.array(images), np.array(labels)

data_path = r"D:\Mohamed Sheriff\Projects\Computer Vision Internship - Cellula Technologies\Water Segementation\Dataset"
images, labels = load_images_and_labels(data_path)

print(f"Loaded {len(images)} images with shape {images[0].shape} and {len(labels)} labels with shape {labels[0].shape}")
print(f"Label Unique Values: {np.unique(labels[0])}")
# Out:
# Loaded 306 images with shape (128, 128, 12) and 306 labels with shape (128, 128)
# Label Unique Values: [0. 1.]

# %%
print(f"{np.max(labels)}")
# Out:
# 1.0

# %% [markdown]
# ### Normalize Data

# %%
def normalize_image(image):
    for channel in range(image.shape[-1]):
        min = np.min(image[:,:,channel], keepdims=True)
        max = np.max(image[:,:,channel],  keepdims=True)
        if max != min:
            image[:,:,channel] = (image[:,:,channel] - min) / (max - min)
        else:
            image[:,:,channel]=0
    return image # Scale values to [0, 1]
        

images = np.array([normalize_image(img) for img in images])

# %% [markdown]
# #### Normalized Difference Water Index Composite $(NDWI)$

# %%
def ndwi(image):
    green_band = image[:, :, 2]  # Assuming Band 2 is Green
    nir_band = image[:, :, 4]    # Assuming Band 4 is NIR
    multispectral_images = (green_band - nir_band) / (green_band + nir_band + 1e-10)  # Avoid division by zero
    return multispectral_images

# %% [markdown]
# ### Visualize Data

# %% [markdown]
# #### Visualize all 12 bands

# %%
for i in range(5):
    print(f"Image {i+1} shape: {images[i].shape}")

    fig, axes = plt.subplots(3, 4, figsize=(15, 10))  # Adjust this to ensure 12 bands are displayed in a grid
    for band in range(images[i].shape[-1]):  # Loop over each band (12 bands)
        axes[band // 4, band % 4].imshow(images[i][:, :, band], cmap='jet')
        axes[band // 4, band % 4].set_title(f'Original Band {band + 1}')
    plt.tight_layout()    
    plt.show()
# Out:
# Image 1 shape: (128, 128, 12)
# Image 2 shape: (128, 128, 12)
# Image 3 shape: (128, 128, 12)
# Image 4 shape: (128, 128, 12)
# Image 5 shape: (128, 128, 12)

# %% [markdown]
# #### RGB composite

# %%
fig, axs = plt.subplots(1, 4, figsize=(20, 10))  

for i in range(4): 
    rgb_image = images[i][:, :, [3, 2, 1]]  # Assuming Bands 1, 2, and 3 are R, G, B
    axs[i].imshow((rgb_image * 512).astype(np.uint8))
    axs[i].set_title(f'RGB Composite Image {i+1}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Visualize NDWI

# %%
fig, axs = plt.subplots(1, 4, figsize=(20, 10))  

for i in range(4):  
    ndwi_image = ndwi(images[i])
    plt.figure(figsize=(5, 5))
    axs[i].imshow(ndwi_image, cmap='Blues')
    axs[i].set_title(f'NDWI Composite Image {i+1}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Visualize Binary Mask for Labels

# %%
fig, axs = plt.subplots(1, 4, figsize=(20, 10))  

for i in range(4):  
    plt.figure(figsize=(5, 5))
    axs[i].imshow(labels[i].squeeze(), cmap='binary')
    axs[i].set_title(f'Label Image {i+1} (Binary Mask)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Reshape Labels for Model Training

# %%
labels.shape , images.shape
# Out:
# ((306, 128, 128), (306, 128, 128, 12))

# %% [markdown]
# ### Model Training

# %%
x_train, x_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=365)
x_test, x_val, y_test, y_val = train_test_split(x_val, y_val, test_size=0.5, random_state=42)

# %% [markdown]
# ### U-Net Model Architecture

# %% [markdown]
# ##### `Encoder`

# %%
def encoder_block(inputs, num_filters):

    x = Conv2D(num_filters, 3, padding='same', kernel_regularizer=regularizers.l2(0.001))(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters, 3, padding='same', kernel_regularizer=regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = MaxPool2D(pool_size=(2, 2), strides=2)(x)

    return x

# %% [markdown]
# ##### `Decoder`

# %%
def decoder_block(inputs, skip_features, num_filters): 

	x = Conv2DTranspose(num_filters, (2, 2), strides = 2, padding = 'same')(inputs) 
	skip_features = tf.image.resize(skip_features, size = (x.shape[1], x.shape[2])) 
	x = tf.keras.layers.Concatenate()([x, skip_features]) 
	
	x = Conv2D(num_filters, 3, padding = 'same', kernel_regularizer=regularizers.l2(0.001))(x) 
	x = Activation('relu')(x) 

	x = Conv2D(num_filters, 3, padding = 'same', kernel_regularizer=regularizers.l2(0.001))(x) 
	x = Activation('relu')(x) 
	
	return x

# %% [markdown]
# ##### `U-Net Model`

# %%
def unet_model(input_shape=(128, 128, 12), num_classes=1):
    inputs = Input(input_shape)

    # Encoding Path
    s1 = encoder_block(inputs, 32)
    s2 = encoder_block(s1, 64)
    s3 = encoder_block(s2, 128)
    s4 = encoder_block(s3, 256)

    # Bottleneck with Dropout
    b1 = Conv2D(512, 3, padding='same', kernel_regularizer=regularizers.l2(0.001))(s4)
    b1 = Activation('relu')(b1)
    # b1 = SpatialDropout2D(0.5)(b1) 
    
    b1 = Conv2D(512, 3, padding='same', kernel_regularizer=regularizers.l2(0.001))(b1)
    b1 = Activation('relu')(b1)
    # b1 = SpatialDropout2D(0.5)(b1) 

    # Decoding Path
    s5 = decoder_block(b1, s4, 256)
    s6 = decoder_block(s5, s3, 128)
    s7 = decoder_block(s6, s2, 64)
    s8 = decoder_block(s7, s1, 32)

    # Output
    outputs = Conv2D(num_classes, 1, padding='same', activation='sigmoid')(s8)

    model = Model(inputs=inputs, outputs=outputs, name='U-Net')
    return model

if __name__ == '__main__':
    model = unet_model(input_shape=(128, 128, 12), num_classes=1)
    model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 2)]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  3488        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 128)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  590080      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 16, 16, 256)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 512)    1180160     ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)      (None, 8, 8, 512)    0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 512)    2359808     ['activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 8, 8, 512)    0           ['conv2d_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 256)  524544     ['activation_9[0][0]']
#  ose)
#
#  tf.image.resize (TFOpLambda)   (None, 16, 16, 256)  0           ['max_pooling2d_3[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'tf.image.resize[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate[0][0]']
#
#  activation_10 (Activation)     (None, 16, 16, 256)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 256)  590080      ['activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 16, 16, 256)  0           ['conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 128)  131200     ['activation_11[0][0]']
#  spose)
#
#  tf.image.resize_1 (TFOpLambda)  (None, 32, 32, 128)  0          ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'tf.image.resize_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_1[0][0]']
#
#  activation_12 (Activation)     (None, 32, 32, 128)  0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  147584      ['activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 32, 32, 128)  0           ['conv2d_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 64)  32832       ['activation_13[0][0]']
#  spose)
#
#  tf.image.resize_2 (TFOpLambda)  (None, 64, 64, 64)  0           ['max_pooling2d_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'tf.image.resize_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_2[0][0]']
#
#  activation_14 (Activation)     (None, 64, 64, 64)   0           ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 64, 64, 64)   0           ['conv2d_15[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 32  8224       ['activation_15[0][0]']
#  spose)                         )
#
#  tf.image.resize_3 (TFOpLambda)  (None, 128, 128, 32  0          ['max_pooling2d[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'tf.image.resize_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 128, 128, 32  0           ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 32  9248        ['activation_16[0][0]']
#                                 )
#
#  activation_17 (Activation)     (None, 128, 128, 32  0           ['conv2d_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  33          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 7,766,529
# Trainable params: 7,764,609
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.00001), 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# %%
model_path = "D:/Mohamed Sheriff/Projects/Computer Vision Internship - Cellula Technologies/Water Segementation/Model/u-net.keras"

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=10, 
    restore_best_weights=True,
  )

CheckPoint = ModelCheckpoint(filepath= model_path , monitor='val_accuracy' ,save_best_only=True , mode='max')

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=5,
    min_lr=1e-5
)

# %%
history = model.fit(
    x_train, y_train,
    epochs=100,
    verbose=1,
    batch_size=16,
    validation_data=(x_val, y_val),
     callbacks=[early_stopping , CheckPoint, reduce_lr]
)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 14s 504ms/step - loss: 3.4962 - accuracy: 0.5283 - val_loss: 3.4277 - val_accuracy: 0.6405 - lr: 1.0000e-05
# Epoch 2/100
# 16/16 [==============================] - 4s 238ms/step - loss: 3.4391 - accuracy: 0.5915 - val_loss: 3.3917 - val_accuracy: 0.6577 - lr: 1.0000e-05
# Epoch 3/100
# 16/16 [==============================] - 4s 264ms/step - loss: 3.3890 - accuracy: 0.6187 - val_loss: 3.3558 - val_accuracy: 0.6677 - lr: 1.0000e-05
# Epoch 4/100
# 16/16 [==============================] - 4s 244ms/step - loss: 3.3426 - accuracy: 0.6407 - val_loss: 3.3202 - val_accuracy: 0.6716 - lr: 1.0000e-05
# Epoch 5/100
# 16/16 [==============================] - 4s 248ms/step - loss: 3.2990 - accuracy: 0.6610 - val_loss: 3.2849 - val_accuracy: 0.6728 - lr: 1.0000e-05
# Epoch 6/100
# 16/16 [==============================] - 4s 241ms/step - loss: 3.2611 - accuracy: 0.6714 - val_loss: 3.2501 - val_accuracy: 0.6734 - lr: 1.0000e-05
# Epoch 7/100
# 16/16 [==============================] - 4s 232ms/step - loss: 3.2186 - accuracy: 0.6772 - val_loss: 3.2156 - val_accuracy: 0.6736 - lr: 1.0000e-05
# Epoch 8/100
# 16/16 [==============================] - 4s 233ms/step - loss: 3.1839 - accuracy: 0.6782 - val_loss: 3.1818 - val_accuracy: 0.6736 - lr: 1.0000e-05
# Epoch 9/100
# 16/16 [==============================] - 4s 227ms/step - loss: 3.1443 - accuracy: 0.6798 - val_loss: 3.1464 - val_accuracy: 0.6737 - lr: 1.0000e-05
# Epoch 10/100
# 16/16 [==============================] - 3s 194ms/step - loss: 3.1077 - accuracy: 0.6793 - val_loss: 3.1128 - val_accuracy: 0.6737 - lr: 1.0000e-05
# Epoch 11/100
# 16/16 [==============================] - 4s 230ms/step - loss: 3.0721 - accuracy: 0.6805 - val_loss: 3.0760 - val_accuracy: 0.6737 - lr: 1.0000e-05
# Epoch 12/100
# 16/16 [==============================] - 3s 194ms/step - loss: 3.0386 - accuracy: 0.6797 - val_loss: 3.0434 - val_accuracy: 0.6737 - lr: 1.0000e-05
# Epoch 13/100
# 16/16 [==============================] - 4s 229ms/step - loss: 3.0135 - accuracy: 0.6795 - val_loss: 3.0127 - val_accuracy: 0.6737 - lr: 1.0000e-05
# Epoch 14/100
# 16/16 [==============================] - 3s 194ms/step - loss: 2.9863 - accuracy: 0.6798 - val_loss: 2.9840 - val_accuracy: 0.6737 - lr: 1.0000e-05
# Epoch 15/100
# 16/16 [==============================] - 3s 194ms/step - loss: 2.9583 - accuracy: 0.6804 - val_loss: 2.9527 - val_accuracy: 0.6737 - lr: 1.0000e-05
# Epoch 16/100
# 16/16 [==============================] - 3s 197ms/step - loss: 2.9307 - accuracy: 0.6809 - val_loss: 2.9251 - val_accuracy: 0.6737 - lr: 1.0000e-05
# Epoch 17/100
# 16/16 [==============================] - 3s 196ms/step - loss: 2.9034 - accuracy: 0.6821 - val_loss: 2.8979 - val_accuracy: 0.6737 - lr: 1.0000e-05
# Epoch 18/100
# 16/16 [==============================] - 3s 196ms/step - loss: 2.8777 - accuracy: 0.6825 - val_loss: 2.8713 - val_accuracy: 0.6736 - lr: 1.0000e-05
# Epoch 19/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.8507 - accuracy: 0.6820 - val_loss: 2.8472 - val_accuracy: 0.6736 - lr: 1.0000e-05
# Epoch 20/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.8255 - accuracy: 0.6828 - val_loss: 2.8208 - val_accuracy: 0.6736 - lr: 1.0000e-05
# Epoch 21/100
# 16/16 [==============================] - 3s 194ms/step - loss: 2.8027 - accuracy: 0.6826 - val_loss: 2.7976 - val_accuracy: 0.6736 - lr: 1.0000e-05
# Epoch 22/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.7782 - accuracy: 0.6827 - val_loss: 2.7721 - val_accuracy: 0.6736 - lr: 1.0000e-05
# Epoch 23/100
# 16/16 [==============================] - 3s 194ms/step - loss: 2.7538 - accuracy: 0.6836 - val_loss: 2.7492 - val_accuracy: 0.6735 - lr: 1.0000e-05
# Epoch 24/100
# 16/16 [==============================] - 3s 191ms/step - loss: 2.7305 - accuracy: 0.6827 - val_loss: 2.7261 - val_accuracy: 0.6734 - lr: 1.0000e-05
# Epoch 25/100
# 16/16 [==============================] - 3s 194ms/step - loss: 2.7084 - accuracy: 0.6835 - val_loss: 2.7028 - val_accuracy: 0.6735 - lr: 1.0000e-05
# Epoch 26/100
# 16/16 [==============================] - 3s 196ms/step - loss: 2.6851 - accuracy: 0.6832 - val_loss: 2.6816 - val_accuracy: 0.6733 - lr: 1.0000e-05
# Epoch 27/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.6634 - accuracy: 0.6839 - val_loss: 2.6591 - val_accuracy: 0.6733 - lr: 1.0000e-05
# Epoch 28/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.6364 - accuracy: 0.6844 - val_loss: 2.6363 - val_accuracy: 0.6733 - lr: 1.0000e-05
# Epoch 29/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.6162 - accuracy: 0.6847 - val_loss: 2.6141 - val_accuracy: 0.6734 - lr: 1.0000e-05
# Epoch 30/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.5960 - accuracy: 0.6845 - val_loss: 2.5942 - val_accuracy: 0.6732 - lr: 1.0000e-05
# Epoch 31/100
# 16/16 [==============================] - 3s 196ms/step - loss: 2.5745 - accuracy: 0.6843 - val_loss: 2.5740 - val_accuracy: 0.6729 - lr: 1.0000e-05
# Epoch 32/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.5519 - accuracy: 0.6847 - val_loss: 2.5520 - val_accuracy: 0.6732 - lr: 1.0000e-05
# Epoch 33/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.5310 - accuracy: 0.6842 - val_loss: 2.5325 - val_accuracy: 0.6733 - lr: 1.0000e-05
# Epoch 34/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.5108 - accuracy: 0.6848 - val_loss: 2.5127 - val_accuracy: 0.6732 - lr: 1.0000e-05
# Epoch 35/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.4918 - accuracy: 0.6846 - val_loss: 2.4935 - val_accuracy: 0.6729 - lr: 1.0000e-05
# Epoch 36/100
# 16/16 [==============================] - 3s 194ms/step - loss: 2.4720 - accuracy: 0.6855 - val_loss: 2.4733 - val_accuracy: 0.6732 - lr: 1.0000e-05
# Epoch 37/100
# 16/16 [==============================] - 3s 195ms/step - loss: 2.4543 - accuracy: 0.6857 - val_loss: 2.4583 - val_accuracy: 0.6728 - lr: 1.0000e-05
# Epoch 38/100
# 16/16 [==============================] - 3s 191ms/step - loss: 2.4344 - accuracy: 0.6855 - val_loss: 2.4377 - val_accuracy: 0.6730 - lr: 1.0000e-05
# Epoch 39/100
# 16/16 [==============================] - 3s 193ms/step - loss: 2.4141 - accuracy: 0.6852 - val_loss: 2.4222 - val_accuracy: 0.6723 - lr: 1.0000e-05
# Epoch 40/100
# 16/16 [==============================] - 3s 193ms/step - loss: 2.3961 - accuracy: 0.6856 - val_loss: 2.4003 - val_accuracy: 0.6730 - lr: 1.0000e-05
# Epoch 41/100
# 16/16 [==============================] - 3s 194ms/step - loss: 2.3779 - accuracy: 0.6852 - val_loss: 2.3858 - val_accuracy: 0.6731 - lr: 1.0000e-05
# Epoch 42/100
# 16/16 [==============================] - 3s 196ms/step - loss: 2.3592 - accuracy: 0.6859 - val_loss: 2.3698 - val_accuracy: 0.6725 - lr: 1.0000e-05
# Epoch 43/100
# 16/16 [==============================] - 3s 196ms/step - loss: 2.3428 - accuracy: 0.6858 - val_loss: 2.3509 - val_accuracy: 0.6726 - lr: 1.0000e-05
# Epoch 44/100
# 16/16 [==============================] - 3s 196ms/step - loss: 2.3234 - accuracy: 0.6862 - val_loss: 2.3360 - val_accuracy: 0.6728 - lr: 1.0000e-05
# Epoch 45/100
# 16/16 [==============================] - 3s 196ms/step - loss: 2.3079 - accuracy: 0.6860 - val_loss: 2.3226 - val_accuracy: 0.6727 - lr: 1.0000e-05
# Epoch 46/100
# 16/16 [==============================] - 3s 192ms/step - loss: 2.2894 - accuracy: 0.6858 - val_loss: 2.3049 - val_accuracy: 0.6725 - lr: 1.0000e-05
# Epoch 47/100
# 16/16 [==============================] - 3s 194ms/step - loss: 2.2694 - accuracy: 0.6859 - val_loss: 2.2954 - val_accuracy: 0.6725 - lr: 1.0000e-05
# Epoch 48/100
# 16/16 [==============================] - 3s 193ms/step - loss: 2.2526 - accuracy: 0.6863 - val_loss: 2.2838 - val_accuracy: 0.6725 - lr: 1.0000e-05
# Epoch 49/100
# 16/16 [==============================] - 3s 193ms/step - loss: 2.2345 - accuracy: 0.6864 - val_loss: 2.2721 - val_accuracy: 0.6723 - lr: 1.0000e-05
# Epoch 50/100
# 16/16 [==============================] - 3s 194ms/step - loss: 2.2225 - accuracy: 0.6862 - val_loss: 2.2709 - val_accuracy: 0.6728 - lr: 1.0000e-05
# Epoch 51/100
# 16/16 [==============================] - 3s 192ms/step - loss: 2.2048 - accuracy: 0.6869 - val_loss: 2.2524 - val_accuracy: 0.6691 - lr: 1.0000e-05
# Epoch 52/100
# 16/16 [==============================] - 3s 193ms/step - loss: 2.1893 - accuracy: 0.6859 - val_loss: 2.2399 - val_accuracy: 0.6725 - lr: 1.0000e-05
# Epoch 53/100
# 16/16 [==============================] - 3s 193ms/step - loss: 2.1731 - accuracy: 0.6869 - val_loss: 2.2353 - val_accuracy: 0.6705 - lr: 1.0000e-05
# Epoch 54/100
# 16/16 [==============================] - 3s 193ms/step - loss: 2.1590 - accuracy: 0.6869 - val_loss: 2.2416 - val_accuracy: 0.6724 - lr: 1.0000e-05
# Epoch 55/100
# 16/16 [==============================] - 3s 194ms/step - loss: 2.1490 - accuracy: 0.6868 - val_loss: 2.2300 - val_accuracy: 0.6724 - lr: 1.0000e-05
# Epoch 56/100
# 16/16 [==============================] - 3s 193ms/step - loss: 2.1310 - accuracy: 0.6878 - val_loss: 2.2139 - val_accuracy: 0.6720 - lr: 1.0000e-05
# Epoch 57/100
# 16/16 [==============================] - 3s 193ms/step - loss: 2.1166 - accuracy: 0.6871 - val_loss: 2.1988 - val_accuracy: 0.6658 - lr: 1.0000e-05
# Epoch 58/100
# 16/16 [==============================] - 3s 191ms/step - loss: 2.1010 - accuracy: 0.6877 - val_loss: 2.1819 - val_accuracy: 0.6720 - lr: 1.0000e-05
# Epoch 59/100
# 16/16 [==============================] - 3s 190ms/step - loss: 2.0825 - accuracy: 0.6876 - val_loss: 2.2049 - val_accuracy: 0.6723 - lr: 1.0000e-05
# Epoch 60/100
# 16/16 [==============================] - 3s 193ms/step - loss: 2.0692 - accuracy: 0.6879 - val_loss: 2.1726 - val_accuracy: 0.6684 - lr: 1.0000e-05
# Epoch 61/100
# 16/16 [==============================] - 3s 190ms/step - loss: 2.0483 - accuracy: 0.6890 - val_loss: 2.1810 - val_accuracy: 0.6587 - lr: 1.0000e-05
# Epoch 62/100
# 16/16 [==============================] - 3s 188ms/step - loss: 2.0286 - accuracy: 0.6914 - val_loss: 2.2331 - val_accuracy: 0.6715 - lr: 1.0000e-05
# Epoch 63/100
# 16/16 [==============================] - 3s 191ms/step - loss: 2.0171 - accuracy: 0.6915 - val_loss: 2.2295 - val_accuracy: 0.6716 - lr: 1.0000e-05
# Epoch 64/100
# 16/16 [==============================] - 3s 192ms/step - loss: 2.0153 - accuracy: 0.6931 - val_loss: 2.1767 - val_accuracy: 0.6645 - lr: 1.0000e-05
# Epoch 65/100
# 16/16 [==============================] - 3s 191ms/step - loss: 1.9984 - accuracy: 0.6947 - val_loss: 2.2313 - val_accuracy: 0.6691 - lr: 1.0000e-05
# Epoch 66/100
# 16/16 [==============================] - 3s 194ms/step - loss: 1.9938 - accuracy: 0.6925 - val_loss: 2.1261 - val_accuracy: 0.6682 - lr: 1.0000e-05
# Epoch 67/100
# 16/16 [==============================] - 3s 192ms/step - loss: 1.9637 - accuracy: 0.6972 - val_loss: 2.1934 - val_accuracy: 0.6634 - lr: 1.0000e-05
# Epoch 68/100
# 16/16 [==============================] - 3s 192ms/step - loss: 1.9539 - accuracy: 0.7020 - val_loss: 2.2153 - val_accuracy: 0.6573 - lr: 1.0000e-05
# Epoch 69/100
# 16/16 [==============================] - 5s 306ms/step - loss: 1.9350 - accuracy: 0.7081 - val_loss: 2.2291 - val_accuracy: 0.6680 - lr: 1.0000e-05
# Epoch 70/100
# 16/16 [==============================] - 3s 191ms/step - loss: 1.9391 - accuracy: 0.7094 - val_loss: 2.1834 - val_accuracy: 0.6667 - lr: 1.0000e-05
# Epoch 71/100
# 16/16 [==============================] - 3s 196ms/step - loss: 1.9725 - accuracy: 0.6950 - val_loss: 2.1026 - val_accuracy: 0.6565 - lr: 1.0000e-05
# Epoch 72/100
# 16/16 [==============================] - 3s 197ms/step - loss: 1.9173 - accuracy: 0.7071 - val_loss: 2.0821 - val_accuracy: 0.6379 - lr: 1.0000e-05
# Epoch 73/100
# 16/16 [==============================] - 3s 190ms/step - loss: 1.9060 - accuracy: 0.7170 - val_loss: 2.1061 - val_accuracy: 0.6320 - lr: 1.0000e-05
# Epoch 74/100
# 16/16 [==============================] - 3s 191ms/step - loss: 1.8858 - accuracy: 0.7202 - val_loss: 2.1305 - val_accuracy: 0.6191 - lr: 1.0000e-05
# Epoch 75/100
# 16/16 [==============================] - 3s 192ms/step - loss: 1.8759 - accuracy: 0.7275 - val_loss: 2.1557 - val_accuracy: 0.6436 - lr: 1.0000e-05
# Epoch 76/100
# 16/16 [==============================] - 3s 193ms/step - loss: 1.8605 - accuracy: 0.7386 - val_loss: 2.1277 - val_accuracy: 0.6026 - lr: 1.0000e-05
# Epoch 77/100
# 16/16 [==============================] - 3s 195ms/step - loss: 1.8468 - accuracy: 0.7506 - val_loss: 2.1490 - val_accuracy: 0.6115 - lr: 1.0000e-05
# Epoch 78/100
# 16/16 [==============================] - 3s 194ms/step - loss: 1.8385 - accuracy: 0.7563 - val_loss: 2.1100 - val_accuracy: 0.6176 - lr: 1.0000e-05
# Epoch 79/100
# 16/16 [==============================] - 3s 196ms/step - loss: 1.8343 - accuracy: 0.7621 - val_loss: 2.2984 - val_accuracy: 0.6579 - lr: 1.0000e-05
# Epoch 80/100
# 16/16 [==============================] - 3s 194ms/step - loss: 1.8226 - accuracy: 0.7646 - val_loss: 2.2554 - val_accuracy: 0.6523 - lr: 1.0000e-05
# Epoch 81/100
# 16/16 [==============================] - 3s 193ms/step - loss: 1.8068 - accuracy: 0.7731 - val_loss: 2.1049 - val_accuracy: 0.5864 - lr: 1.0000e-05
# Epoch 82/100
# 16/16 [==============================] - 3s 198ms/step - loss: 1.8003 - accuracy: 0.7722 - val_loss: 2.1115 - val_accuracy: 0.5878 - lr: 1.0000e-05

# %% [markdown]
# ### Evaluation

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
def visualize_predictions(images, labels, predictions, num_images=5):
    """
    Visualize the original images, predicted masks, and ground truth masks side by side.
    
    Parameters:
    - images: The original input images (e.g., multispectral).
    - labels: Ground truth binary masks.
    - predictions: Predicted binary masks from the model.
    - num_images: Number of images to visualize.
    """
    for i in range(num_images):
        # Original image (Assuming RGB composite for visualization)
        rgb_image = images[i][:, :, [1,2,3]]  # Adjust the bands for RGB composite (if applicable)
        rgb_image = (rgb_image * 255).astype(np.uint8)  # Scale for visualization

        # Check if the predictions have an extra dimension and handle accordingly
        predicted_mask = predictions[i]
        if predicted_mask.shape[-1] == 1:  # If it has an extra dimension (128, 128, 1)
            predicted_mask = np.squeeze(predicted_mask, axis=-1)  # Remove the extra dimension

        # Ground truth mask
        ground_truth = labels[i]

        # Plot side by side
        fig, axs = plt.subplots(1, 3, figsize=(15, 5))

        axs[0].imshow(rgb_image)
        axs[0].set_title(f'Original Image {i+1}')
        axs[0].axis('off')

        axs[1].imshow(predicted_mask, cmap='gray')
        axs[1].set_title(f'Predicted Mask {i+1}')
        axs[1].axis('off')

        axs[2].imshow(ground_truth, cmap='gray')
        axs[2].set_title(f'Ground Truth Mask {i+1}')
        axs[2].axis('off')

        plt.show()

# %%
visualize_predictions(images, labels, y_pred, num_images=5)
