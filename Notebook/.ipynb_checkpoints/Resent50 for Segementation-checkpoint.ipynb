# %% [markdown]
#  ### Import Libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from sklearn.metrics import jaccard_score, precision_score, recall_score, f1_score
import tifffile as tiff
from PIL import Image

import tensorflow as tf
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, UpSampling2D, SpatialDropout2D,concatenate, Activation, Conv2DTranspose, MaxPool2D, BatchNormalization, Dropout
from tensorflow.keras import Model, layers, regularizers
from tensorflow.keras.callbacks import ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.models import load_model
from keras import layers
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split


from tensorflow.keras.initializers import HeNormal
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Load and Explore Dataset

# %%
def load_images_and_labels(data_path):
    images_path = os.path.join(data_path, 'images')
    labels_path = os.path.join(data_path, 'labels')
    
    image_files = [f for f in os.listdir(images_path) if f.endswith('.tif')]
    label_files = [f for f in os.listdir(labels_path) if f.endswith('.png')]
    
    images = []
    labels = []
    
    for img_file, lbl_file in zip(image_files, label_files):
        img = tiff.imread(os.path.join(images_path, img_file))
       # Load the label .png image, convert to numpy array and normalize
        lbl = Image.open(os.path.join(labels_path, lbl_file))
        lbl = np.array(lbl).astype(np.float32)
        
        # Labels should be binary (0 and 1), so ensure proper normalization
        #lbl = lbl / 255.0
        
        images.append(img)
        labels.append(lbl)
    
    return np.array(images), np.array(labels)

data_path = r"D:\Mohamed Sheriff\Projects\Computer Vision Internship - Cellula Technologies\Water Segementation\Dataset"
images, labels = load_images_and_labels(data_path)

print(f"Loaded {len(images)} images with shape {images[0].shape} and {len(labels)} labels with shape {labels[0].shape}")
# Out:
# Loaded 306 images with shape (128, 128, 12) and 306 labels with shape (128, 128)

# %% [markdown]
# ### Normalize Data

# %%
def normalize_image(image):
    for channel in range(image.shape[-1]):
        min = np.min(image[:,:,channel], keepdims=True)
        max = np.max(image[:,:,channel],  keepdims=True)
        if max != min:
            image[:,:,channel] = (image[:,:,channel] - min) / (max - min)
        else:
            image[:,:,channel]=0
    return image # Scale values to [0, 1]
        

images = np.array([normalize_image(img) for img in images])
# labels = np.array([normalize_image(lab) for lab in labels])

# %% [markdown]
# #### Normalized Difference Water Index Composite $(NDWI)$

# %%
def ndwi(image):
    green_band = image[:, :, 2]  # Assuming Band 2 is Green
    nir_band = image[:, :, 4]    # Assuming Band 4 is NIR
    multispectral_images = (green_band - nir_band) / (green_band + nir_band + 1e-10)  # Avoid division by zero
    return multispectral_images

# %% [markdown]
# ### Visualize Data

# %% [markdown]
# #### Visualize all 12 bands

# %%
for i in range(5):
    print(f"Image {i+1} shape: {images[i].shape}")

    fig, axes = plt.subplots(3, 4, figsize=(15, 10))  # Adjust this to ensure 12 bands are displayed in a grid
    for band in range(images[i].shape[-1]):  # Loop over each band (12 bands)
        axes[band // 4, band % 4].imshow(images[i][:, :, band], cmap='jet')
        axes[band // 4, band % 4].set_title(f'Original Band {band + 1}')
    plt.tight_layout()    
    plt.show()
# Out:
# Image 1 shape: (128, 128, 12)
# Image 2 shape: (128, 128, 12)
# Image 3 shape: (128, 128, 12)
# Image 4 shape: (128, 128, 12)
# Image 5 shape: (128, 128, 12)

# %% [markdown]
# #### RGB composite

# %%
fig, axs = plt.subplots(1, 4, figsize=(20, 10))  

for i in range(4): 
    rgb_image = images[i][:, :, [3, 2, 1]]  # Assuming Bands 1, 2, and 3 are R, G, B
    axs[i].imshow((rgb_image * 512).astype(np.uint8))
    axs[i].set_title(f'RGB Composite Image {i+1}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Visualize NDWI

# %%
fig, axs = plt.subplots(1, 4, figsize=(20, 10))  

for i in range(4):  
    ndwi_image = ndwi(images[i])
    plt.figure(figsize=(5, 5))
    axs[i].imshow(ndwi_image, cmap='Blues')
    axs[i].set_title(f'NDWI Composite Image {i+1}')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Visualize Binary Mask for Labels

# %%
fig, axs = plt.subplots(1, 4, figsize=(20, 10))  

for i in range(4):  
    plt.figure(figsize=(5, 5))
    axs[i].imshow(labels[i].squeeze(), cmap='binary')
    axs[i].set_title(f'Label Image {i+1} (Binary Mask)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Reshape Labels for Model Training

# %%
labels.shape , images.shape
# Out:
# ((306, 128, 128), (306, 128, 128, 12))

# %%
# labels = labels.reshape(-1, 128, 128, 1) #labels will contain multiple 128x128 single-channel images.
# labels.shape , images.shape

# %% [markdown]
# ### Model Training

# %%
x_train, x_val, y_train, y_val = train_test_split(images, labels, test_size=0.2, random_state=365)
x_test, x_val, y_test, y_val = train_test_split(x_val, y_val, test_size=0.5, random_state=42)

# %% [markdown]
# ### U-Net Model Architecture

# %% [markdown]
# ##### `Encoder`

# %%
def encoder_block(inputs, num_filters):

    # Convolution with 3x3 filter followed by ReLU activation
    x = Conv2D(num_filters, 3, padding='same', kernel_regularizer=regularizers.l2(0.001))(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Convolution with 3x3 filter followed by ReLU activation
    x = Conv2D(num_filters, 3, padding='same', kernel_regularizer=regularizers.l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Max Pooling with 2x2 filter
    x = MaxPool2D(pool_size=(2, 2), strides=2)(x)

    return x

# %% [markdown]
# ##### `Decoder`

# %%
def decoder_block(inputs, skip_features, num_filters): 

	# Upsampling with 2x2 filter 
	x = Conv2DTranspose(num_filters, (2, 2), strides = 2, padding = 'same')(inputs) 
	
	# Copy and crop the skip features 
	# to match the shape of the upsampled input 
	skip_features = tf.image.resize(skip_features, size = (x.shape[1], x.shape[2])) 
	x = tf.keras.layers.Concatenate()([x, skip_features]) 
	
	# Convolution with 3x3 filter followed by ReLU activation 
	x = Conv2D(num_filters, 3, padding = 'same', kernel_regularizer=regularizers.l2(0.001))(x) 
	x = Activation('relu')(x) 

	# Convolution with 3x3 filter followed by ReLU activation 
	x = Conv2D(num_filters, 3, padding = 'same', kernel_regularizer=regularizers.l2(0.001))(x) 
	x = Activation('relu')(x) 
	
	return x

# %% [markdown]
# ##### `U-Net Model`

# %%
# def unet_model(input_shape=(128, 128, 12), num_classes=1):
#     inputs = Input(input_shape)

#     # Encoding Path
#     s1 = encoder_block(inputs, 32)
#     s2 = encoder_block(s1, 64)
#     # s3 = encoder_block(s2, 128)
#     # s4 = encoder_block(s3, 256)

#     # Bottleneck with Dropout
#     b1 = Conv2D(128, 3, padding='same', kernel_regularizer=regularizers.l2(0.001))(s2)
#     b1 = Activation('relu')(b1)
#     b1 = SpatialDropout2D(0.5)(b1) 
    
#     b1 = Conv2D(128, 3, padding='same', kernel_regularizer=regularizers.l2(0.001))(b1)
#     b1 = Activation('relu')(b1)
#     b1 = SpatialDropout2D(0.5)(b1) 

#     # Decoding Path
#     # s5 = decoder_block(b1, s4, 256)
#     # s6 = decoder_block(s5, s3, 128)
#     s7 = decoder_block(b1, s2, 64)
#     s8 = decoder_block(s7, s1, 32)

#     # Output
#     outputs = Conv2D(num_classes, 1, padding='same', activation='sigmoid')(s8)

#     model = Model(inputs=inputs, outputs=outputs, name='U-Net')
#     return model

# if __name__ == '__main__':
#     model = unet_model(input_shape=(128, 128, 12), num_classes=1)
#     model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 2)]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  3488        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)      (None, 32, 32, 128)  0           ['conv2d_4[0][0]']
#
#  spatial_dropout2d (SpatialDrop  (None, 32, 32, 128)  0          ['activation_4[0][0]']
#  out2D)
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['spatial_dropout2d[0][0]']
#
#  activation_5 (Activation)      (None, 32, 32, 128)  0           ['conv2d_5[0][0]']
#
#  spatial_dropout2d_1 (SpatialDr  (None, 32, 32, 128)  0          ['activation_5[0][0]']
#  opout2D)
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 64)  32832       ['spatial_dropout2d_1[0][0]']
#  ose)
#
#  tf.image.resize (TFOpLambda)   (None, 64, 64, 64)   0           ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 128)  0           ['conv2d_transpose[0][0]',
#                                                                   'tf.image.resize[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 64)   73792       ['concatenate[0][0]']
#
#  activation_6 (Activation)      (None, 64, 64, 64)   0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 64)   36928       ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 64, 64, 64)   0           ['conv2d_7[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 32  8224       ['activation_7[0][0]']
#  spose)                         )
#
#  tf.image.resize_1 (TFOpLambda)  (None, 128, 128, 32  0          ['max_pooling2d[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_1[0][0]',
#                                 )                                 'tf.image.resize_1[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 32  18464       ['concatenate_1[0][0]']
#                                 )
#
#  activation_8 (Activation)      (None, 128, 128, 32  0           ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 128, 128, 32  9248        ['activation_8[0][0]']
#                                 )
#
#  activation_9 (Activation)      (None, 128, 128, 32  0           ['conv2d_9[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 1)  33          ['activation_9[0][0]']
#
# ==================================================================================================
# Total params: 469,889
# Trainable params: 469,505
# Non-trainable params: 384
# __________________________________________________________________________________________________

# %%
def unet_model(input_shape):
    inputs = tf.keras.layers.Input(input_shape)

    # Encoder
    c1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

    c2 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

    # Bottleneck
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c5)

    # Decoder
    u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c2])
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u6)
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c6)

    u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = tf.keras.layers.concatenate([u7, c1])
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u7)
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c7)

    outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c7)

    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
model = unet_model(input_shape=(128, 128, 12))
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 2)]
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 64  6976        ['input_2[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_11[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 64)  0           ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_13[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 128)  0          ['conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 256)  590080      ['conv2d_15[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  131200     ['conv2d_16[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_2[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 128)  147584      ['conv2d_17[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  32832      ['conv2d_18[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'conv2d_12[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 64  36928       ['conv2d_19[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 1)  65          ['conv2d_20[0][0]']
#
# ==================================================================================================
# Total params: 1,868,033
# Trainable params: 1,868,033
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=Adam(), 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# %%
model_path = "D:/Mohamed Sheriff/Projects/Computer Vision Internship - Cellula Technologies/Water Segementation/Model/u-net.keras"

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=7, 
    restore_best_weights=True,
  )

CheckPoint = ModelCheckpoint(filepath= model_path , monitor='val_accuracy' ,save_best_only=True , mode='max')

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=5,
    min_lr=1e-5
)

# %%
history = model.fit(
    x_train, y_train,
    epochs=100,
    verbose=1,
    batch_size=32,
    validation_data=(x_val, y_val),
     callbacks=[early_stopping , CheckPoint, reduce_lr]
)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 14s 1s/step - loss: 0.6799 - accuracy: 0.6827 - val_loss: 0.6536 - val_accuracy: 0.6740 - lr: 0.0010
# Epoch 2/100
# 8/8 [==============================] - 4s 491ms/step - loss: 0.6427 - accuracy: 0.6847 - val_loss: 0.6320 - val_accuracy: 0.6740 - lr: 0.0010
# Epoch 3/100
# 8/8 [==============================] - 4s 485ms/step - loss: 0.6242 - accuracy: 0.6847 - val_loss: 0.6330 - val_accuracy: 0.6740 - lr: 0.0010
# Epoch 4/100
# 8/8 [==============================] - 4s 486ms/step - loss: 0.6226 - accuracy: 0.6847 - val_loss: 0.6310 - val_accuracy: 0.6740 - lr: 0.0010
# Epoch 5/100
# 8/8 [==============================] - 4s 486ms/step - loss: 0.6225 - accuracy: 0.6847 - val_loss: 0.6330 - val_accuracy: 0.6740 - lr: 0.0010
# Epoch 6/100
# 8/8 [==============================] - 4s 486ms/step - loss: 0.6234 - accuracy: 0.6878 - val_loss: 0.6328 - val_accuracy: 0.6740 - lr: 0.0010
# Epoch 7/100
# 8/8 [==============================] - 4s 557ms/step - loss: 0.6237 - accuracy: 0.6879 - val_loss: 0.6314 - val_accuracy: 0.6740 - lr: 0.0010
# Epoch 8/100
# 8/8 [==============================] - 4s 523ms/step - loss: 0.6217 - accuracy: 0.6879 - val_loss: 0.6343 - val_accuracy: 0.6740 - lr: 0.0010
# Epoch 9/100
# 8/8 [==============================] - 4s 533ms/step - loss: 0.6198 - accuracy: 0.6879 - val_loss: 0.6311 - val_accuracy: 0.6741 - lr: 0.0010
# Epoch 10/100
# 8/8 [==============================] - 4s 524ms/step - loss: 0.6194 - accuracy: 0.6879 - val_loss: 0.6310 - val_accuracy: 0.6741 - lr: 1.0000e-04
# Epoch 11/100
# 8/8 [==============================] - 4s 484ms/step - loss: 0.6193 - accuracy: 0.6879 - val_loss: 0.6311 - val_accuracy: 0.6741 - lr: 1.0000e-04
# Epoch 12/100
# 8/8 [==============================] - 4s 485ms/step - loss: 0.6190 - accuracy: 0.6879 - val_loss: 0.6314 - val_accuracy: 0.6741 - lr: 1.0000e-04
# Epoch 13/100
# 8/8 [==============================] - 4s 483ms/step - loss: 0.6192 - accuracy: 0.6879 - val_loss: 0.6317 - val_accuracy: 0.6741 - lr: 1.0000e-04
# Epoch 14/100
# 8/8 [==============================] - 4s 483ms/step - loss: 0.6189 - accuracy: 0.6879 - val_loss: 0.6314 - val_accuracy: 0.6741 - lr: 1.0000e-04
# Epoch 15/100
# 8/8 [==============================] - 4s 486ms/step - loss: 0.6189 - accuracy: 0.6879 - val_loss: 0.6314 - val_accuracy: 0.6741 - lr: 1.0000e-05
# Epoch 16/100
# 8/8 [==============================] - 4s 483ms/step - loss: 0.6189 - accuracy: 0.6879 - val_loss: 0.6314 - val_accuracy: 0.6741 - lr: 1.0000e-05
# Epoch 17/100
# 8/8 [==============================] - 4s 487ms/step - loss: 0.6189 - accuracy: 0.6879 - val_loss: 0.6314 - val_accuracy: 0.6741 - lr: 1.0000e-05

# %% [markdown]
# ##
